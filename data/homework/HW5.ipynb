# %% [markdown]
# ### Ориентировочный план

# %% [markdown]
# - [ ] Создать новую ветку с именем hw5 с помощью команды
# ```
# git checkout -b hw5
# ```
# - [ ] Создать новый файл HW5.ipynb
# - [ ] Исправить README.md в с соответствии с текущим состоянием репозитория
# - [ ] Оба файла добавить в staging и создать коммит
# ```
# git add -A
# git commit -m "<...>"
# ```
# - [ ] Запушить коммит в удаленный репозиторий на гитхабе
# - [ ] Создать PR через web ui гитхаба, одобрить, слить ветки
