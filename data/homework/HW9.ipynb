# %% [markdown]
# ### Задание 1

# %%
import re

# %%
PATTERN = r'([АВЕКМНОРСТУХ]\d{3}[АВЕКМНОРСТУХ]{2})(\d{2,3})'


def is_valid_plate_number(plate_number: str):
    match = re.match(PATTERN, plate_number)
    if match:
        return True, match.groups()[0], match.groups()[1]
    else:
        return False, None, None


def validate(plate_number: str):
    is_valid, number, region = is_valid_plate_number(plate_number)
    if is_valid:
        print(f'Номер {number} валиден. Регион: {region}.')
    else:
        print('Номер не валиден.')

validate('А222ВС96')
validate('АБ22ВВ193')
# Out:
# Номер А222ВС валиден. Регион: 96.
# Номер не валиден.

# %% [markdown]
# ### Задание 2

# %%
def eliminate_repetitions(text: str) -> str:
    return re.sub(r'\b(\w+)(\s\1\b)+', r'\1', text)

# %%
some_string = 'Напишите функцию функцию, которая будет будет будет будет удалять все все все все последовательные повторы слов из из из из заданной строки строки при помощи регулярных выражений'
print(eliminate_repetitions(some_string))
# Out:
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки при помощи регулярных выражений
